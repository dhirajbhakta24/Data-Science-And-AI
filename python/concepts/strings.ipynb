# %%
print("Hello, starting with strings ")
# Out:
# Hello, starting with strings

# %%
name = "Dhiraj is learning python"
language = "Python"
message = """
this is 
a multiline 
string
"""
print(name,language,message)
# Out:
# Dhiraj is learning python Python
# this is
# a multiline
# string
#
# test

# %%
###string is immutable
# you cannot edit a string after its creation if want to perform some operation on strings then you have to store the output in other variable 
# because the orignal string will not be changed 
#

# %%
quote = "Python is amazing"
print(quote[0])
print(quote[:5])
print(quote[-1])
print(quote[3:])
print(quote[:-1])

#string is immutable in the below example the string is not changed but the variable is given a new value
#so the test variable value is changed rather than the string 

test = "testing"
test = "test"
print(test)
# Out:
# P
# Pytho
# g
# hon is amazing
# Python is amazin

# %%
###split is used to split the string on the basis what we provide in the split method 
###split returns the output in list 
quote.split(" ")
# Out:
# ['Python', 'is', 'amazing']

# %%
plus =  name + "," + quote
print(plus)
# Out:
# Dhiraj is learning python,Python is amazing

# %% [markdown]
# 5. Slicing with Step
#
# Syntax:
#
# string[start:stop:step]
#
# Example:
#
# text = "Python"
#
#
# print(text[::2])
#
# Output:
#
# Pto

# %%
text = "ABCDEFG"

print(text[::2])
print(text[::-2])
print(text[1::2])

print(text[-1:-5:-1])
# Out:
# ACEG
# GECA
# BDF
#
# GFED

# %%
print(text[-1:-5:-1])
# Out:
# GFED

# %%
length = print(len(text))
# Out:
# 7

# %% [markdown]
# ###String Methods

# %%
# len calculates the length of string
length = print(len(text))
# Out:
# 7

# %%
for char in text:
    print(char,end=" ")
# Out:
# A B C D E F G

# %%
###Membership Operator
###You can check whether something exists. in , not in
textt = "I am learning Python"
print("Python" in textt)
print("Java" in textt)
print("Java" not in textt)
# Out:
# True
# False
# True

# %%
s = "saksham and dhiraj are friends"
ss = s.upper()

# %%
###upper() -> converts all the character in lower 
print(s.upper())
# Out:
# SAKSHAM AND DHIRAJ ARE FRIENDS

# %%
###lower()
print(ss.lower())
# Out:
# saksham and dhiraj are friends

# %%
###capatialize -> it capitalize the first letter of the first word in the string 
print(s.capitalize())
# Out:
# Saksham and dhiraj are friends

# %%
###title - capitalize first letter of each strings 
print(s.title())
# Out:
# Saksham And Dhiraj Are Friends

# %%
t = "PyThOn"
print(t.swapcase())
# Out:
# pYtHoN

# %%
###replace -> replace the word with another word
## since string are immutable it returns a new string 
new_friends = s.replace("saksham","biswa")
print(new_friends)
# Out:
# biswa and dhiraj are friends

# %%
###find
### it returns the index of the first letter of the word we are searching or starting index of the word we are searching
### in the string and if the word is not present then it return -1
print(s.find("dhiraj"))
print(s.find("biswa"))
# Out:
# 12
# -1

# %%
###startswith() and endswith()
url = "https://example.com"
gmail = "sakshamprem2003@gmail.com"
print(gmail.endswith(".com"))
print(url.startswith("https"))
# Out:
# True
# True

# %%
##Count 
### it counts the no of occurence in can also work on substrings###
f = "banana and apple"
print(f.count("a"))
print(f.count("b"))
print(f.count("an"))
# Out:
# 5
# 1
# 3

# %%
### split and join
#split()
#String → List

#join()
#List → String
 ###

l = "java python javascript"
language = l.split()
print(language)

la ="$".join(language)
print(la)
# Out:
# ['java', 'python', 'javascript']
# java$python$javascript

# %%
###partition() it returns a 3 element tuple
####



email = "dhiraj@example.com"


result = email.partition("@")


print(result)
# Out:
# ('dhiraj', '@', 'example.com')

# %%
text = "Python is an amazing programming language"

vowel_count=0
con_count = 0
unique_char = 0
longest_word = ""
maxlen = 0
my_set = set()

split_text = text.split()

word_count = len(split_text)

# Find longest word
for word in split_text:
    word_length = len(word)

    if word_length > maxlen:
        longest_word = word
        maxlen = word_length


    

for char in text:
    my_set.add(char)
    
    if(char.lower() in 'aeiou'):
        vowel_count += 1
    
    else:
        con_count += 1
    
print(vowel_count)
print(word_count)
print(con_count)
print(len(my_set))
print(longest_word)
# Out:
# 13
# 6
# 28
# 18
# programming
